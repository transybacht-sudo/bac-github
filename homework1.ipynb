# %% [markdown]
# bài 1

# %%
n = int(input())
print("so gap doi cua n la:",n * 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 n = int(input())
#       2 print("so gap doi cua n la:",n * 2)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# bài 2

# %%
a = float(input())
b = float(input())
pi = 3.14
r = a / 2
dien_tich_hinh_chu_nhat = a * b
dien_tich_hinh_tron = pi * r * r
dien_tich_trong_cay = dien_tich_hinh_chu_nhat - dien_tich_hinh_tron
print("dien tich trong cay:", round(dien_tich_trong_cay, 2))
# Out:
# dien tich trong cay: 7.44

# %% [markdown]
# bài 3

# %%
c = input()
if c.isupper():
   print("chu thuong:", c.lower())
else:
     print("chu hoa:", c.upper())
# Out:
# chu hoa: C

# %% [markdown]
# bai

# %% [markdown]
# bài 4

# %%
c = input()
if c.isalpha():
   print(c, "la ky tu alphabet")
else:
   print(c, "khong phai là ky tu alphabet")
# Out:
# c la ky tu alphabet

# %% [markdown]
# bài 5

# %%
c = input()
a = c.lower()
if a == 'a':
    print("truong hop dac biet")
else:
    print("chu cai truoc la:", chr(ord(a) - 1))
# Out:
# chu cai truoc la: a

# %% [markdown]
# bài 6

# %%
a = float(input())
b = float(input())
c = float(input())
if a + b > c and b+c > a and a + c > b
   p = (a + b + c) / 3
   s = math.sqrt(p * (p-a) * (p -b) * (p-c))
   print("dien_tich_tam_giac:", round(s,1))
else
