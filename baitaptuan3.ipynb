# %% [markdown]
# W3A1

# %%
n = input()
a = n[::-1]
print(a)
# Out:
# 65

# %% [markdown]
# W3A2

# %%
a, b = map(int, input().split())
a = a ^ b
b = a ^ b
a = a ^ b

print(n)
# Out:
# (5, 4)

# %% [markdown]
# W3A3

# %%
n = int(input())
if n > 0 and (n & (n-1)) == 0:
    print("n là lũy thừa của 2")
else:
    print("n không phải là lũy thừa của 2")
# Out:
# n là lũy thừa của 2

# %% [markdown]
# W3A4

# %%
m ,n = map(int, input().split())
a = m // n
print(a.__floor__())
# Out:
# 1

# %% [markdown]
# W3A5

# %%
m, n = map(int, input().split())
a = m // n
print(a.__ceil__())
# Out:
# 1

# %% [markdown]
# W3A6

# %%
x = int(input())
if x % 2 == 0:
    print("Even")
if x % 2 != 0:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# W3A7

# %%
a, b = map(int, input().split())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# W3A8

# %%
a = input()
b = input()
n = str(a)
m = str(b)
p = len(n)
q = len(m)
if p > q:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# W3A9

# %%
a, b, c = map(int, input().split())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# W3A10

# %%
a, b, c, d = map(int, input().split())
print(max(a, b, c, d))
# Out:
# 4

# %% [markdown]
# W3A11

# %%
a, b, c = map(int, input().split())
if a + b > c and a + c > b and b + c > a:
    print("Tam giac thuong")
elif a == b == c:
    ptinr("Tam giac deu")
elif a == b or a == c or b == c:
    print("Tam giac can")
elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
    print("Tam gia3 4 5c vuong")
else:
    print("Khong phai tam giac")
# Out:
# Tam giac thuong

# %% [markdown]
# W3A12

# %%
n = int(input())
if n % 4 == 0 and (n % 100 != 0 or n % 400 == 0):
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# W3A13

# %%
n = int(input())
if 0 <= n <= 50:
    a = 1500 * n
    print(a)
elif 50 < n <= 100:
    a = 1500 * 50 + 1200 * (n - 50)
    print(a)
elif 100 < n:
    a = 1500 * 50 + 1200 * 50 + 1000 * (n - 100)
    print(a)
# Out:
# 1935000

# %% [markdown]
# W3A14

# %%
a, b = map(int, input().split())
if a != 0 and b != 0:
    x = a/b
    print(x)
if a == 0 and b != 0:
    print("Vô nghiệm")
if a == 0 and b == 0:
    print("Vô số nghiệm")
# Out:
# 1.3333333333333333

# %% [markdown]
# W3A15

# %%
n = float(input())
if n >= 8.0:
    print("Gioi")
elif n >= 6.5:
    print("Kha")
elif n >= 5.0:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Gioi
